# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array(np.arange(0.001,11,0.001))
# y = 10+(np.log(x/10)/.5)
y1 = 10*np.exp(.5*(x1-10))

fig, ax = plt.subplots()
# ax.set_title('LOTR')
ax.set_ylabel('LOTR Limit Token Value')
ax.set_yticks([2,4,6,8], minor=True)
ax.set_yticks([0,10], minor=False)
ax.set_yticklabels([0,'Limit Price'])
ax.yaxis.grid(True, which='major')
ax.set_ylim([0,10])
ax.set_xticks([2,4,6,8], minor=True)
ax.set_xticks([0,10], minor=False)
ax.set_xticklabels([0,'Limit Price'])
ax.set_xlabel('Target Asset Market Price')
ax.xaxis.grid(True, which='major')
ax.set_xlim([0,10])
ax.plot(x1, y1, color='purple', marker='', linestyle='solid', linewidth=3, markersize=0)
# plt.draw()
# plt.savefig('./litepaper/images/graph_limit_below.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
# x2 = np.array(np.arange(0.001,10,0.001))
y2 = 10-(10*np.exp(.5*(x2-10)))

fig, ax = plt.subplots()
# ax.set_title('LOTR')
ax.set_ylabel('LOTR Redeem Token Value')
ax.set_yticks([2,4,6,8], minor=True)
ax.set_yticks([0,10], minor=False)
# ax.set_yticklabels(['Limit Price',r'$+\infty$'])
ax.set_yticklabels([0,'Limit Price'])
ax.yaxis.grid(True, which='major')
ax.set_ylim([0,10])
ax.set_xticks([2,4,6,8], minor=True)
ax.set_xticks([0,10], minor=False)
ax.set_xticklabels([0,'Limit Price'])
ax.set_xlabel('Target Asset Market Price')
ax.xaxis.grid(True, which='major')
ax.set_xlim([0,10])
ax.plot(x1, y1, color='purple', marker='', linestyle='solid', linewidth=3, markersize=0, label="test")
ax.plot(x2, y2, color='black', marker='', linestyle='solid', linewidth=3, markersize=0)
# plt.draw()
# plt.savefig('./litepaper/images/graph_redeem_below.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
x1 = np.array(np.arange(0.001,21,0.001))
y1 = 10*np.exp(.5*(10-x1))

fig, ax = plt.subplots()
# ax.set_title('LOTR')
ax.set_ylabel('LOTR Limit Token Value')
ax.set_yticks([2,4,6,8], minor=True)
ax.set_yticks([0,10], minor=False)
ax.set_yticklabels([0,'Limit Price'])
ax.yaxis.grid(True, which='major')
ax.set_ylim([0,10])
ax.set_xticks([12,14,16,18], minor=True)
ax.set_xticks([10,20], minor=False)
ax.set_xticklabels(['Limit Price',r'$+\infty$'])
ax.set_xlabel('Target Asset Market Price')
ax.xaxis.grid(True, which='major')
ax.set_xlim([10,20])
ax.plot(x1, y1, color='purple', marker='', linestyle='solid', linewidth=3, markersize=0)
# plt.draw()
# plt.savefig('./litepaper/images/graph_limit_above.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
x2 = np.array(np.arange(0.001,21,0.001))
y2 = 10-(10*np.exp(.5*(10-x2)))

fig, ax = plt.subplots()
# ax.set_title('LOTR')
ax.set_ylabel('LOTR Redeem Token Value')
ax.set_yticks([2,4,6,8], minor=True)
ax.set_yticks([0,10], minor=False)
ax.set_yticklabels([0,'Limit Price'])
ax.yaxis.grid(True, which='major')
ax.set_ylim([0,10])
ax.set_xticks([12,14,16,18], minor=True)
ax.set_xticks([10,20], minor=False)
ax.set_xticklabels(['Limit Price',r'$+\infty$'])
ax.set_xlabel('Target Asset Market Price')
ax.xaxis.grid(True, which='major')
ax.set_xlim([10,20])
ax.plot(x1, y1, color='purple', marker='', linestyle='solid', linewidth=3, markersize=0)
ax.plot(x2, y2, color='black', marker='', linestyle='solid', linewidth=3, markersize=0)
# plt.draw()
# plt.savefig('./litepaper/images/graph_redeem_above.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
np.exp(.0001*(-9))
# Out:
# 0.9991004048785274

# %%
np.log(1/10)
# Out:
# -2.3025850929940455

# %%
10-(10*np.exp(.5*(10-15)))
# Out:
# 9.179150013761012

# %%
x = np.array(np.arange(0.001,21,0.001))
y = 0.001*x**4

fig, ax = plt.subplots()
ax.set_ylim([0,10])
ax.set_xlim([0,10])
ax.plot(x, y, color='purple', marker='', linestyle='solid', linewidth=3, markersize=0)
plt.show()

# %%
x = np.array(np.arange(0.001,21,0.001))
y = 0.2 - (-0.002/-0.8)*(1 - np.exp(+0.8*x))

fig, ax = plt.subplots()
ax.set_ylim([0,10])
ax.set_xlim([0,10])
ax.plot(x, y, color='purple', marker='', linestyle='solid', linewidth=3, markersize=0)
plt.show()
